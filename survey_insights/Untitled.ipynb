# %%
# %pip install pyreadstat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def read_file(path):
    df, meta = pyreadstat.read_sav(path)
    var_labels, val_labels = meta.column_names_to_labels, meta.variable_value_labels
    return df, var_labels, val_labels

# %%
path = "C:\\Users\\adako\\Documents\\survey\\survey_insights\\mzd.sav"

# %%
print(path)
# Out:
# C:\Users\adako\Documents\survey\survey_insights\mzd.sav

# %%
x, y, z = read_file(path)

# %%
y
# Out:
# {'id': 'Внутренний идентификатор респондента в опросе',
#  'ac': 'Аксесс код респондента',
#  'starttime': 'Дата начала прохождения опроса',
#  'endtime': 'Дата окончания прохождения опроса',
#  'Qweek': 'Неделя',
#  'QGENDER': 'Укажите Ваш пол:',
#  'QDataDay': 'Дата рождения - день',
#  'QDataMonth': 'Дата рождения - месяц',
#  'QDataYear': 'Дата рождения - год',
#  'QAGE': '/Укажите дату Вашего рождения./',
#  'QAGEGR': 'ЗАКОДИРОВАТЬ ВОЗРАСТНУЮ ГРУППУ:',
#  'QCITY': 'В каком городе Вы проживаете в настоящее время?',
#  'QDISTRICT': '/ЗАКОДИРОВАТЬ ФО./',
#  'QSTRATA': '/ЗАКОДИРОВАТЬ СТРАТУ. /',
#  'S1': 'В какой области Вы работаете (учитесь)?',
#  'QA1_1': 'Впишите, пожалуйста, марки автомобилей, которые Вы знаете, не важно, был ли у Вас опыт вождения автомобилей этой марки или нет. - Марка 1',
#  'QA1_2': 'Впишите, пожалуйста, марки автомобилей, которые Вы знаете, не важно, был ли у Вас опыт вождения автомобилей этой марки или нет. - Марка 2',
# ...

# %%
"id" in z
# Out:
# False

# %%
# Out:
# {0.0: 'unchecked', 1.0: 'checked'}

# %%
import pyreadstat

# %%
x, meta = pyreadstat.read_sav("mzd.sav")

# %%
meta.column_labels
# Out:
# ['Внутренний идентификатор респондента в опросе',
#  'Аксесс код респондента',
#  'Дата начала прохождения опроса',
#  'Дата окончания прохождения опроса',
#  'Неделя',
#  'Укажите Ваш пол:',
#  'Дата рождения - день',
#  'Дата рождения - месяц',
#  'Дата рождения - год',
#  '/Укажите дату Вашего рождения./',
#  'ЗАКОДИРОВАТЬ ВОЗРАСТНУЮ ГРУППУ:',
#  'В каком городе Вы проживаете в настоящее время?',
#  '/ЗАКОДИРОВАТЬ ФО./',
#  '/ЗАКОДИРОВАТЬ СТРАТУ. /',
#  'В какой области Вы работаете (учитесь)?',
#  'Впишите, пожалуйста, марки автомобилей, которые Вы знаете, не важно, был ли у Вас опыт вождения автомобилей этой марки или нет. - Марка 1',
#  'Впишите, пожалуйста, марки автомобилей, которые Вы знаете, не важно, был ли у Вас опыт вождения автомобилей этой марки или нет. - Марка 2',
#  'Впишите, пожалуйста, марки автомобилей, которые Вы знаете, не важно, был ли у Вас опыт вождения автомобилей этой марки или нет. - Марка 3',
# ...

# %%
meta.variable_value_labels
# Out:
# {'Qweek': {1.0: 'week 1',
#   2.0: 'week 2',
#   3.0: 'week 3',
#   4.0: 'week 4',
#   99.0: 'Переменная не пришла'},
#  'QGENDER': {1.0: 'Мужской', 2.0: 'Женский'},
#  'QDataDay': {1.0: '1',
#   2.0: '2',
#   3.0: '3',
#   4.0: '4',
#   5.0: '5',
#   6.0: '6',
#   7.0: '7',
#   8.0: '8',
#   9.0: '9',
#   10.0: '10',
#   11.0: '11',
#   12.0: '12',
#   13.0: '13',
#   14.0: '14',
#   15.0: '15',
#   16.0: '16',
#   17.0: '17',
#   18.0: '18',
#   19.0: '19',
#   20.0: '20',
#   21.0: '21',
#   22.0: '22',
#   23.0: '23',
#   24.0: '24',
#   25.0: '25',
#   26.0: '26',
#   27.0: '27',
#   28.0: '28',
#   29.0: '29',
#   30.0: '30',
#   31.0: '31'},
#  'QDataMonth': {1.0: 'Января',
#   2.0: 'Февраля',
#   3.0: 'Марта',
#   4.0: 'Апреля',
#   5.0: 'Мая',
#   6.0: 'Июня',
#   7.0: 'Июля',
#   8.0: 'Августа',
#   9.0: 'Сентября',
#   10.0: 'Октября',
#   11.0: 'Ноября',
#   12.0: 'Декабря'},
#  'QDataYear': {1910.0: '1910',
#   1911.0: '1911',
#   1912.0: '1912',
#   1913.0: '1913',
# ...

# %%
records = savReaderWriter.SavReader("mzd.sav")

# %%
with savReaderWriter.SavReader ("mzd.sav", ioUtf8=True) as reader:
    x = reader.varLabels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\savReaderWriter\header.py in wrapper(arg)
#      59                 try:
# ---> 60                     for i, j in v.items():  # or wrapper(j) recursion?
#      61                         uresult[uS(k)][uS(i)] = uS(uL(j))
#
# AttributeError: 'bytes' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-43-6ea2b518f671> in <module>
#       1 with savReaderWriter.SavReader ("mzd.sav", ioUtf8=True) as reader:
# ----> 2     x = reader.varLabels
#
# ~\anaconda3\lib\site-packages\savReaderWriter\header.py in wrapper(arg)
#      61                         uresult[uS(k)][uS(i)] = uS(uL(j))
#      62                 except AttributeError:
# ...

# %%
x
# Out:
# [b'id',
#  b'ac',
#  b'starttime',
#  b'endtime',
#  b'Qweek',
#  b'QGENDER',
#  b'QDataDay',
#  b'QDataMonth',
#  b'QDataYear',
#  b'QAGE',
#  b'QAGEGR',
#  b'QCITY',
#  b'QDISTRICT',
#  b'QSTRATA',
#  b'S1',
#  b'QA1_1',
#  b'QA1_2',
#  b'QA1_3',
#  b'QA1_4',
#  b'QA1_5',
#  b'QA1_6',
#  b'QA1o1',
#  b'QA1o2',
#  b'QA1o3',
#  b'QA1o4',
#  b'QA1o5',
#  b'QA1o6',
#  b'QA2_1',
#  b'QA2_2',
#  b'QA2_3',
#  b'QA2_4',
#  b'QA2_5',
#  b'QA2_6',
#  b'QA2o1',
#  b'QA2o2',
#  b'QA2o3',
#  b'QA2o4',
#  b'QA2o5',
#  b'QA2o6',
#  b'QA3_1',
#  b'QA3_2',
#  b'QA3_3',
#  b'QA3_4',
#  b'QA3_5',
#  b'QA3_6',
#  b'QA3o1',
#  b'QA3o2',
#  b'QA3o3',
#  b'QA3o4',
#  b'QA3o5',
#  b'QA3o6',
#  b'QS2',
#  b'QS3p1',
#  b'QS3p2',
#  b'QS4',
#  b'QS5',
#  b'QS6',
#  b'QS7',
#  b'QS8',
#  b'QS9p1_1',
#  b'QS9p1_2',
#  b'QS9p1_3',
#  b'QS9p1_6',
#  b'QS9p1_7',
#  b'QS9p1_8',
#  b'QS9p1_9',
#  b'QS9p1_10',
#  b'QS9p1_11',
#  b'QS9p1_12',
#  b'QS9p1_13',
#  b'QS9p1_14',
#  b'QS9p1_15',
#  b'QS9p1_17',
# ...
